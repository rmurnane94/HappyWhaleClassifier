# %% [markdown]
# # Image Classification ML Assignment
#
# The goal of this assignment is to learn fundamentals of machine learning and image analysis. You will analyze images from Happy Whale, an organization that tracks whales globally, and modify a classifier for these images.
#
# Part 1: Walk through (Due Feb 27)
# - In class, we will walk through the provided code
# - This script has several functions that are written for you. For part 1, please do NOT modify any code unless it specifies to change it.
# - Answer the questions as you go through the code
#
# Part 2: Make modifications (Due Feb 27)
# - Change model parameters or other model aspects at least 3 times
# - Describe what happened when you made these changes
#
# Part 3: Create a team, get inspired and try a new approach to your model (Due March 6)
# - Have a group meeting and record your meeting with audio or video (you can record with zoom!)
#     - Start by discussing part 2 of the assignment:
#         - What approaches you each took to change the ML model in part 2
#         - What are similarities and differences between your approaches
#         - What types of changes improved model performance
#         - What types of changes made model performance worse
#         - Based on the whole group's work, what would y'all want to do next in terms of model optimization?
#     - Next, look at code and approaches from the [Happy Whales competition leaderboard](https://www.kaggle.com/competitions/happy-whale-and-dolphin/leaderboard).
#         - Is there any strategy that someone used that you could implement?
#             - Ex: learning rate value, # epochs, transformation strategy, or more complex changes to the models
#         - Are there strategies that you are interested in learning about?
#     - Lastly, make a plan for 1 more round of model optimization
#         - Assign each member something to attempt for training the model. Use your cumulative experience to decide the most important things to test.
#         - Group members can make as small as changing the value for a parameter or as big as changing the model.
# - Have each member complete their test
# - Share results with each other
# - Write a 1-3 paragraph summary on your group's attempts and recommendations moving forward
# - For Part 3: Turn in the audio/video recording of the group meeting, each member's code (uploaded to their original git repo), and the team's 1-3 paragraph summary over canvas.

# %% [markdown]
# ### Your choices on data
# You can chose between 3 datasets for this assignment. This jupyter notebook is set up using the Species dataset. If you change the dataset, you will need to change the number of classes parameter for the model.
# - Species = you will classify images by species (gray, killer, beluga, humpback, false killer, and common dolphin)
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
# - Species_all = you will classify images by species (minke, gray, killer, beluga, humpback, false killer, and bottlenose and common dolphin). There are a high number of images for bottlenose dolphins and minke whales which leads to this dataset being quite large. Due to the size of the dataset, it has a longer training time than the "Species" dataset.
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species_all
#   - Num classes: 8
# - Individuals = you will classify images by individuals. This is a much more challenging classification task because you have different individuals from different species. However, this was the original goal of the Happy Whale competition, so try challenging yourself to this important task!
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/individuals
#   - Num classes: 110
#
# You are NOT graded by the success of your model, so you are free to train the model on whichever dataset is more interesting to you. However, **everyone on your team for part 3 should be using the same dataset**.

# %% [markdown]
# ### Part 1

# %%
## Importing packages - Please DO NOT alter this box ##
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data.sampler import WeightedRandomSampler
torch.manual_seed(0)

from captum.attr import IntegratedGradients
from captum.attr import DeepLift
from captum.attr import NoiseTunnel
from captum.attr import visualization as viz

import torchvision
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tqdm import tqdm
from scipy.ndimage import binary_erosion
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

import wandb #comment this out if you are not using weights and biases
import random #comment this out if you are not using weights and biases

# Set device to cuda if it's available otherwise default to "cpu"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# ### Loading in the dataset
#
# By default, this will load in the species dataset, this is the smallest dataset (i.e., it will be relatively fast to train) and has a simple goal (i.e., you will be able to create an accurate model). If you want a challenge, I highly encourage you to try the Species_all (a dataset with 2 additional species) or the individual dataset (a dataset where whales are characterized by individual rather than species).

# %%
images = "/projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species"

# %%
# We must turn our images into tensors, resize, and normalize them 
# We can also add additional transformations to images 
transform = transforms.Compose([transforms.ToTensor(), 
                                #We will start with a model called Resnet18 that is optimized for 224x224 images
                                #It is set to a very SMALL size initially so the model will train fast in class
                                transforms.Resize([32,32]),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences)
                               ])
all_images = datasets.ImageFolder(images, transform)
print(all_images)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# <font color='magenta'>What is the purpose(s) of transforming image data? (2 pts)

# %% [markdown]
# The model works with tensor data, not images, so each image has to be transformed to a tensor so the image data can be analyzed. Then the data is resized which makes sure the images are the same size, and shrinking the size can also make the model faster. The data is also normalized so the model does not get thrown off by color variation.

# %% [markdown]
# <font color='green'>The below code completes the image transformations as coded in the above box.

# %%
all_images = datasets.ImageFolder(images, transform )
print(len(all_images))
print(all_images)
# Out:
# 2794
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Our classification labels will be converted to indices, we can determine which indices is which label using the below code

# %%
print(all_images.class_to_idx)
# Out:
# {'beluga': 0, 'common_dolphin': 1, 'false_killer_whale': 2, 'fin_whale': 3, 'gray_whale': 4, 'humpback_whale': 5}

# %% [markdown]
# <font color='green'>The below function is used to randomly select dataset images to evaluate how the transformations altered the images.

# %%
def show_random_dataset_image(dataset):
    idx = np.random.randint(0, len(dataset))    # take a random sample
    img, mask = dataset[idx]                    # get the image and the nuclei masks
    f, axarr = plt.subplots(1, 2)               # make two plots on one figure
    axarr[0].imshow(img[0], cmap="viridis")                     # show the image, cmap is the color map that the image is being shown in
    #axarr[1].imshow(mask[0])                    # show the masks
    _ = [ax.axis('off') for ax in axarr]        # remove the axes
    print('Image size is %s' % {img[0].shape})
    print(img.shape)
    plt.show()

# %%
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([32, 32])}
# torch.Size([3, 32, 32])

# %% [markdown]
# <font color='magenta'>What is the difference between image size and torch image size? (2 pts)

# %% [markdown]
# The image size here is 32x32 pixels. The torch image size includes the channels first so it is 3 color channels x 32x32 pixels.

# %% [markdown]
# <font color='magenta'>Add a new transformation to the training data. After your first run of this model during class time, resize the image to 224x224 pixels. (2 pts)

# %%
## ADD YOUR TRANSFORMATION HERE
transform = transforms.Compose([
            transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))
            transforms.RandomHorizontalFlip(p=0.5), #adding horizontal flip
            transforms.RandomRotation(10), #added for model 3
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), #added for model 3
            ]) 

all_images = datasets.ImageFolder(images, transform )
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([224, 224])}
# torch.Size([3, 224, 224])

# %% [markdown]
# <font color='magenta'>How did your transformation impact the images? (1 pt)

# %% [markdown]
# It flipped it over from left to right

# %% [markdown]
# ### Creating datasets used in training and testing
#
# After loading in the data, we separate the data into training, validation, and testing datasets. The training data is inputted into the model during the training phase, and the model's predictions from this data is used to modulate the weights of the model. The validation data is used while the model trains, but the model is in a evaluation rather than training mode. The validation data gives us a real time view on how accurately the model is predicting our labels. The testing data is used after the model has completed training and tells us how successful our model will be with a novel dataset.
#
# Once creating these 3 datasets, we prepare dataloaders which are used to load the images into our models. These images are loaded in batches into the model (a parameter called batch size). Because our dataset is imbalanced, we use a weighted random sampler to select images for our batches in the dataloader. Therefore to create our dataloader, we start by creating a function to get weights, calculating weights, initiating our weighted random sampler, and then creating our dataloaders.

# %% [markdown]
# <font color='green'>The below code eastablishes the data split between training, validation, and testing.

# %%
train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
print(train_size, val_size, test_size)
assert train_size + val_size + test_size == len(all_images)
# Out:
# 1955 419 420

# %%
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])

# %% [markdown]
# <font color='green'>The below function is used to get weights for the image classes.

# %%
def _get_weights(subset,full_dataset):
    ys = np.array([y for _, y in subset])
    counts = np.bincount(ys)
    label_weights = 1.0 / counts
    weights = label_weights[ys]

    print("Number of images per class:")
    for c, n, w in zip(full_dataset.classes, counts, label_weights):
        print(f"\t{c}:\tn={n}\tweight={w}")
        
    return weights

# %%
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
# Out:
# Number of images per class:
# 	beluga:	n=474	weight=0.002109704641350211
# 	common_dolphin:	n=44	weight=0.022727272727272728
# 	false_killer_whale:	n=721	weight=0.0013869625520110957
# 	fin_whale:	n=120	weight=0.008333333333333333
# 	gray_whale:	n=54	weight=0.018518518518518517
# 	humpback_whale:	n=542	weight=0.0018450184501845018

# %% [markdown]
# <font color='magenta'>What is the impact of the class weight on how data is loaded into the model? What does it mean if a class has a low vs high weight? (2 pts)

# %% [markdown]
# <details>
#   <summary>Hint</summary>
#
# Check out this resource: https://towardsdatascience.com/demystifying-pytorchs-weightedrandomsampler-by-example-a68aceccb452

# %% [markdown]
# The class weight makes sure that the data loaded in the model has more equal representation of all classes. Classes with higher counts get lower weights. Classes with lower counts get higher weights.

# %%
train_loader = DataLoader(train_set, batch_size=48, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=48, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=48, drop_last=True, shuffle=True)

# %% [markdown]
# ### Picking hyperparameters
#
# We can set a few hyperparameters that we decide and can tune. These include:
#
# - Learning rate = how much to update our model's parameters at each batch/epoch
# - batch size = the number of data samples to pass through the network before updating it
#     - If you change the batchsize below, make sure you ALSO change it in the commands above for the DataLoader
# - Number of epochs = # of times to iterate over the dataset in model training

# %%
learning_rate=1e-3
batchsize=48
epochs=5

# %% [markdown]
# <font color='magenta'>How would model training be impacted if we decreased our learning rate? What about if we increased it? (2 pts)

# %% [markdown]
# Learning rate affects how the model calculates loss. Decreasing the learning rate will lower the speed of the model training but could help with accuracy as it makes smaller adjustments. Increasing the learning rate will make training faster but perhaps more inaccurate if its adjustments are too large.

# %% [markdown]
# ### Training our model
#
# For part 1, we are going to use the model ResNet18. This is a published model for imaging data. Resnet18 is built from 4 residual blocks with two convolutional layers (Conv2d). Each convolutional layer is followed by a batch normalization step (BatchNorm2D) and a ReLU activation layer (ReLU). There is also a shortcut connection which adds input to output and allows the network to learn residual mapping.
#
# I provided the complete code for the ResNet18 model. In the future, if you want to use resnet18, you can load it simply by running `resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)`. We will look at the full code for the model so you can see how this model was created.

# %% [markdown]
# <font color='green'>The below code builds the residual blocks that ResNet18 uses in the model.

# %%
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    # Initializing method for the basic block (It's OOP!)
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

# %% [markdown]
# <font color='green'>The below code builds and initializes the ResNet18 model.

# %%
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)
print(model)
# Out:
# ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %% [markdown]
# <font color='green'>The below code eastablishes the loss function and optimizer used in training the model.

# %%
#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# <font color='green'>The below functions are used to train, evaluate, and test the Machine Learning model.

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Ryan-HappyWhale-SpeciesDataset-hyperparameters", ### Update with your name!
    config={"learning rate":0.001,
        "architecture": "CNN",
        "dataset": "Species",
        "epochs":5}
)

num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0
    batch=0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/rmurnane/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_134939-hru0gy43</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/hru0gy43' target="_blank">Ryan-HappyWhale-SpeciesDataset-hyperparameters</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/hru0gy43' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/hru0gy43</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 27.08%
# Epoch [1/5] | Batch #2 | Batch Accuracy 30.21%
# Epoch [1/5] | Batch #3 | Batch Accuracy 29.17%
# Epoch [1/5] | Batch #4 | Batch Accuracy 26.56%
# Epoch [1/5] | Batch #5 | Batch Accuracy 26.25%
# Epoch [1/5] | Batch #6 | Batch Accuracy 28.12%
# Epoch [1/5] | Batch #7 | Batch Accuracy 29.76%
# Epoch [1/5] | Batch #8 | Batch Accuracy 30.47%
# Epoch [1/5] | Batch #9 | Batch Accuracy 31.94%
# Epoch [1/5] | Batch #10 | Batch Accuracy 33.54%
# Epoch [1/5] | Batch #11 | Batch Accuracy 34.66%
# Epoch [1/5] | Batch #12 | Batch Accuracy 35.42%
# Epoch [1/5] | Batch #13 | Batch Accuracy 36.22%
# Epoch [1/5] | Batch #14 | Batch Accuracy 37.95%
# Epoch [1/5] | Batch #15 | Batch Accuracy 37.78%
# Epoch [1/5] | Batch #16 | Batch Accuracy 38.67%
# Epoch [1/5] | Batch #17 | Batch Accuracy 39.58%
# Epoch [1/5] | Batch #18 | Batch Accuracy 40.05%
# Epoch [1/5] | Batch #19 | Batch Accuracy 40.68%
# Epoch [1/5] | Batch #20 | Batch Accuracy 42.19%
# Epoch [1/5] | Batch #21 | Batch Accuracy 43.25%
# Epoch [1/5] | Batch #22 | Batch Accuracy 44.03%
# Epoch [1/5] | Batch #23 | Batch Accuracy 44.38%
# Epoch [1/5] | Batch #24 | Batch Accuracy 44.88%
# Epoch [1/5] | Batch #25 | Batch Accuracy 45.58%
# Epoch [1/5] | Batch #26 | Batch Accuracy 46.07%
# Epoch [1/5] | Batch #27 | Batch Accuracy 46.14%
# Epoch [1/5] | Batch #28 | Batch Accuracy 46.35%
# Epoch [1/5] | Batch #29 | Batch Accuracy 46.98%
# Epoch [1/5] | Batch #30 | Batch Accuracy 47.36%
# Epoch [1/5] | Batch #31 | Batch Accuracy 47.65%
# Epoch [1/5] | Batch #32 | Batch Accuracy 48.11%
# Epoch [1/5] | Batch #33 | Batch Accuracy 48.67%
# Epoch [1/5] | Batch #34 | Batch Accuracy 48.90%
# Epoch [1/5] | Batch #35 | Batch Accuracy 48.93%
# Epoch [1/5] | Batch #36 | Batch Accuracy 49.19%
# Epoch [1/5] | Batch #37 | Batch Accuracy 49.49%
# Epoch [1/5] | Batch #38 | Batch Accuracy 49.84%
# Epoch [1/5] | Batch #39 | Batch Accuracy 49.73%
# Epoch [1/5] | Batch #40 | Batch Accuracy 50.10%
# Epoch [1/5] Train Loss: 1.4126 | Train Acc: 50.10% | Val Acc: 45.31% | Val Loss: 1.45%
# Epoch [2/5] | Batch #1 | Batch Accuracy 58.33%
# Epoch [2/5] | Batch #2 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #3 | Batch Accuracy 61.81%
# Epoch [2/5] | Batch #4 | Batch Accuracy 61.46%
# Epoch [2/5] | Batch #5 | Batch Accuracy 62.50%
# Epoch [2/5] | Batch #6 | Batch Accuracy 62.50%
# Epoch [2/5] | Batch #7 | Batch Accuracy 63.69%
# Epoch [2/5] | Batch #8 | Batch Accuracy 62.76%
# Epoch [2/5] | Batch #9 | Batch Accuracy 62.96%
# Epoch [2/5] | Batch #10 | Batch Accuracy 63.12%
# Epoch [2/5] | Batch #11 | Batch Accuracy 62.31%
# Epoch [2/5] | Batch #12 | Batch Accuracy 61.98%
# Epoch [2/5] | Batch #13 | Batch Accuracy 61.22%
# Epoch [2/5] | Batch #14 | Batch Accuracy 61.01%
# Epoch [2/5] | Batch #15 | Batch Accuracy 61.67%
# Epoch [2/5] | Batch #16 | Batch Accuracy 61.98%
# Epoch [2/5] | Batch #17 | Batch Accuracy 61.64%
# Epoch [2/5] | Batch #18 | Batch Accuracy 62.04%
# Epoch [2/5] | Batch #19 | Batch Accuracy 61.84%
# Epoch [2/5] | Batch #20 | Batch Accuracy 62.08%
# Epoch [2/5] | Batch #21 | Batch Accuracy 61.61%
# Epoch [2/5] | Batch #22 | Batch Accuracy 61.36%
# Epoch [2/5] | Batch #23 | Batch Accuracy 61.59%
# Epoch [2/5] | Batch #24 | Batch Accuracy 62.07%
# Epoch [2/5] | Batch #25 | Batch Accuracy 62.08%
# Epoch [2/5] | Batch #26 | Batch Accuracy 62.10%
# Epoch [2/5] | Batch #27 | Batch Accuracy 61.88%
# Epoch [2/5] | Batch #28 | Batch Accuracy 61.98%
# Epoch [2/5] | Batch #29 | Batch Accuracy 61.93%
# Epoch [2/5] | Batch #30 | Batch Accuracy 62.15%
# Epoch [2/5] | Batch #31 | Batch Accuracy 62.16%
# Epoch [2/5] | Batch #32 | Batch Accuracy 61.98%
# Epoch [2/5] | Batch #33 | Batch Accuracy 61.68%
# Epoch [2/5] | Batch #34 | Batch Accuracy 61.83%
# Epoch [2/5] | Batch #35 | Batch Accuracy 62.08%
# Epoch [2/5] | Batch #36 | Batch Accuracy 62.21%
# Epoch [2/5] | Batch #37 | Batch Accuracy 62.33%
# Epoch [2/5] | Batch #38 | Batch Accuracy 62.06%
# Epoch [2/5] | Batch #39 | Batch Accuracy 62.07%
# Epoch [2/5] | Batch #40 | Batch Accuracy 62.34%
# Epoch [2/5] Train Loss: 1.0063 | Train Acc: 62.34% | Val Acc: 53.91% | Val Loss: 1.26%
# Epoch [3/5] | Batch #1 | Batch Accuracy 72.92%
# Epoch [3/5] | Batch #2 | Batch Accuracy 77.08%
# Epoch [3/5] | Batch #3 | Batch Accuracy 73.61%
# Epoch [3/5] | Batch #4 | Batch Accuracy 69.27%
# Epoch [3/5] | Batch #5 | Batch Accuracy 69.58%
# Epoch [3/5] | Batch #6 | Batch Accuracy 68.40%
# Epoch [3/5] | Batch #7 | Batch Accuracy 68.45%
# Epoch [3/5] | Batch #8 | Batch Accuracy 68.23%
# Epoch [3/5] | Batch #9 | Batch Accuracy 67.82%
# Epoch [3/5] | Batch #10 | Batch Accuracy 67.29%
# Epoch [3/5] | Batch #11 | Batch Accuracy 67.61%
# Epoch [3/5] | Batch #12 | Batch Accuracy 67.88%
# Epoch [3/5] | Batch #13 | Batch Accuracy 66.83%
# Epoch [3/5] | Batch #14 | Batch Accuracy 66.82%
# Epoch [3/5] | Batch #15 | Batch Accuracy 66.81%
# Epoch [3/5] | Batch #16 | Batch Accuracy 66.41%
# Epoch [3/5] | Batch #17 | Batch Accuracy 66.18%
# Epoch [3/5] | Batch #18 | Batch Accuracy 66.09%
# Epoch [3/5] | Batch #19 | Batch Accuracy 65.46%
# Epoch [3/5] | Batch #20 | Batch Accuracy 65.94%
# Epoch [3/5] | Batch #21 | Batch Accuracy 66.87%
# Epoch [3/5] | Batch #22 | Batch Accuracy 66.76%
# Epoch [3/5] | Batch #23 | Batch Accuracy 66.85%
# Epoch [3/5] | Batch #24 | Batch Accuracy 67.01%
# Epoch [3/5] | Batch #25 | Batch Accuracy 67.08%
# Epoch [3/5] | Batch #26 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #27 | Batch Accuracy 66.28%
# Epoch [3/5] | Batch #28 | Batch Accuracy 66.15%
# Epoch [3/5] | Batch #29 | Batch Accuracy 66.16%
# Epoch [3/5] | Batch #30 | Batch Accuracy 66.32%
# Epoch [3/5] | Batch #31 | Batch Accuracy 66.20%
# Epoch [3/5] | Batch #32 | Batch Accuracy 66.60%
# Epoch [3/5] | Batch #33 | Batch Accuracy 66.79%
# Epoch [3/5] | Batch #34 | Batch Accuracy 66.24%
# Epoch [3/5] | Batch #35 | Batch Accuracy 66.25%
# Epoch [3/5] | Batch #36 | Batch Accuracy 66.61%
# Epoch [3/5] | Batch #37 | Batch Accuracy 66.61%
# Epoch [3/5] | Batch #38 | Batch Accuracy 66.34%
# Epoch [3/5] | Batch #39 | Batch Accuracy 66.29%
# Epoch [3/5] | Batch #40 | Batch Accuracy 66.30%
# Epoch [3/5] Train Loss: 0.8754 | Train Acc: 66.30% | Val Acc: 44.53% | Val Loss: 1.36%
# Epoch [4/5] | Batch #1 | Batch Accuracy 70.83%
# Epoch [4/5] | Batch #2 | Batch Accuracy 62.50%
# Epoch [4/5] | Batch #3 | Batch Accuracy 63.89%
# Epoch [4/5] | Batch #4 | Batch Accuracy 63.02%
# Epoch [4/5] | Batch #5 | Batch Accuracy 64.58%
# Epoch [4/5] | Batch #6 | Batch Accuracy 64.24%
# Epoch [4/5] | Batch #7 | Batch Accuracy 65.48%
# Epoch [4/5] | Batch #8 | Batch Accuracy 66.41%
# Epoch [4/5] | Batch #9 | Batch Accuracy 65.51%
# Epoch [4/5] | Batch #10 | Batch Accuracy 66.46%
# Epoch [4/5] | Batch #11 | Batch Accuracy 67.23%
# Epoch [4/5] | Batch #12 | Batch Accuracy 67.19%
# Epoch [4/5] | Batch #13 | Batch Accuracy 67.63%
# Epoch [4/5] | Batch #14 | Batch Accuracy 68.01%
# Epoch [4/5] | Batch #15 | Batch Accuracy 67.64%
# Epoch [4/5] | Batch #16 | Batch Accuracy 68.36%
# Epoch [4/5] | Batch #17 | Batch Accuracy 68.01%
# Epoch [4/5] | Batch #18 | Batch Accuracy 67.71%
# Epoch [4/5] | Batch #19 | Batch Accuracy 67.76%
# Epoch [4/5] | Batch #20 | Batch Accuracy 67.81%
# Epoch [4/5] | Batch #21 | Batch Accuracy 68.15%
# Epoch [4/5] | Batch #22 | Batch Accuracy 68.18%
# Epoch [4/5] | Batch #23 | Batch Accuracy 68.03%
# Epoch [4/5] | Batch #24 | Batch Accuracy 68.14%
# Epoch [4/5] | Batch #25 | Batch Accuracy 68.17%
# Epoch [4/5] | Batch #26 | Batch Accuracy 68.43%
# Epoch [4/5] | Batch #27 | Batch Accuracy 68.83%
# Epoch [4/5] | Batch #28 | Batch Accuracy 69.05%
# Epoch [4/5] | Batch #29 | Batch Accuracy 69.04%
# Epoch [4/5] | Batch #30 | Batch Accuracy 68.96%
# Epoch [4/5] | Batch #31 | Batch Accuracy 68.95%
# Epoch [4/5] | Batch #32 | Batch Accuracy 68.29%
# Epoch [4/5] | Batch #33 | Batch Accuracy 68.37%
# Epoch [4/5] | Batch #34 | Batch Accuracy 68.38%
# Epoch [4/5] | Batch #35 | Batch Accuracy 68.33%
# Epoch [4/5] | Batch #36 | Batch Accuracy 68.11%
# Epoch [4/5] | Batch #37 | Batch Accuracy 67.79%
# Epoch [4/5] | Batch #38 | Batch Accuracy 67.43%
# Epoch [4/5] | Batch #39 | Batch Accuracy 67.41%
# Epoch [4/5] | Batch #40 | Batch Accuracy 67.66%
# Epoch [4/5] Train Loss: 0.8507 | Train Acc: 67.66% | Val Acc: 54.95% | Val Loss: 1.15%
# Epoch [5/5] | Batch #1 | Batch Accuracy 75.00%
# Epoch [5/5] | Batch #2 | Batch Accuracy 78.12%
# Epoch [5/5] | Batch #3 | Batch Accuracy 74.31%
# Epoch [5/5] | Batch #4 | Batch Accuracy 73.44%
# Epoch [5/5] | Batch #5 | Batch Accuracy 73.33%
# Epoch [5/5] | Batch #6 | Batch Accuracy 72.57%
# Epoch [5/5] | Batch #7 | Batch Accuracy 74.40%
# Epoch [5/5] | Batch #8 | Batch Accuracy 75.52%
# Epoch [5/5] | Batch #9 | Batch Accuracy 75.23%
# Epoch [5/5] | Batch #10 | Batch Accuracy 74.58%
# Epoch [5/5] | Batch #11 | Batch Accuracy 74.24%
# Epoch [5/5] | Batch #12 | Batch Accuracy 74.13%
# Epoch [5/5] | Batch #13 | Batch Accuracy 74.04%
# Epoch [5/5] | Batch #14 | Batch Accuracy 73.07%
# Epoch [5/5] | Batch #15 | Batch Accuracy 73.47%
# Epoch [5/5] | Batch #16 | Batch Accuracy 73.18%
# Epoch [5/5] | Batch #17 | Batch Accuracy 73.53%
# Epoch [5/5] | Batch #18 | Batch Accuracy 72.80%
# Epoch [5/5] | Batch #19 | Batch Accuracy 73.25%
# Epoch [5/5] | Batch #20 | Batch Accuracy 73.33%
# Epoch [5/5] | Batch #21 | Batch Accuracy 73.61%
# Epoch [5/5] | Batch #22 | Batch Accuracy 73.77%
# Epoch [5/5] | Batch #23 | Batch Accuracy 74.09%
# Epoch [5/5] | Batch #24 | Batch Accuracy 74.57%
# Epoch [5/5] | Batch #25 | Batch Accuracy 74.42%
# Epoch [5/5] | Batch #26 | Batch Accuracy 73.88%
# Epoch [5/5] | Batch #27 | Batch Accuracy 73.69%
# Epoch [5/5] | Batch #28 | Batch Accuracy 73.88%
# Epoch [5/5] | Batch #29 | Batch Accuracy 73.42%
# Epoch [5/5] | Batch #30 | Batch Accuracy 72.85%
# Epoch [5/5] | Batch #31 | Batch Accuracy 72.11%
# Epoch [5/5] | Batch #32 | Batch Accuracy 72.33%
# Epoch [5/5] | Batch #33 | Batch Accuracy 72.60%
# Epoch [5/5] | Batch #34 | Batch Accuracy 72.73%
# Epoch [5/5] | Batch #35 | Batch Accuracy 72.80%
# Epoch [5/5] | Batch #36 | Batch Accuracy 72.92%
# Epoch [5/5] | Batch #37 | Batch Accuracy 72.80%
# Epoch [5/5] | Batch #38 | Batch Accuracy 72.75%
# Epoch [5/5] | Batch #39 | Batch Accuracy 72.86%
# Epoch [5/5] | Batch #40 | Batch Accuracy 72.66%
# Epoch [5/5] Train Loss: 0.7307 | Train Acc: 72.66% | Val Acc: 60.42% | Val Loss: 1.00%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▄▂▂▁</td></tr><tr><td>validation_accuracy</td><td>▁▅▁▆█</td></tr><tr><td>validation_loss</td><td>█▅▇▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.73068</td></tr><tr><td>validation_accuracy</td><td>60.41667</td></tr><tr><td>validation_loss</td><td>0.99531</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ryan-HappyWhale-SpeciesDataset-hyperparameters</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/hru0gy43' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/hru0gy43</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_134939-hru0gy43/logs</code>

# %% [markdown]
# #### For our class training, run the below model and consider the success of the model training.
#
# <font color='magenta'>What is your starting accuracy and final accuracy? What happened to the model to change the accuracy from epoch 1 to 5? (2 pts)

# %% [markdown]
# The validation accuracy after epoch 1 is 45.31% and after epoch 5 it is 60.42%. After each batch the model calculates the loss to see how incorrect the predictions are compared to the actual species present in each image. The loss.backward command then calculates the gradients which the optimizer.step command uses to update the parameters of the model.

# %%
plt.plot(range(num_epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(num_epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()

# %% [markdown]
# <font color='green'>After running the model and calculating the overall accuracy, we can examine the data via a confusion matrix which highlights the accuracy by class.

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

## This plot only contains the test set of data
## The test set of data has not been seen by the model yet
y_pred, y_true = predict(model, test_set)

print(y_true)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# [5 2 5 2 0 3 5 0 5 0 4 0 2 2 5 5 2 2 0 5 2 2 2 2 1 0 3 5 5 2 3 5 2 2 0 2 2
#  5 2 0 5 2 0 0 5 0 5 2 2 2 2 0 2 0 2 2 2 2 0 5 0 2 3 3 4 4 2 2 2 5 2 2 0 0
#  0 0 0 0 0 2 2 2 2 4 5 0 5 2 0 2 5 2 2 2 5 2 3 2 0 5 2 3 0 0 0 2 2 2 2 2 5
#  0 0 2 2 1 5 3 2 5 5 5 2 3 2 2 2 0 5 0 5 2 5 5 3 1 2 5 0 0 2 5 5 0 5 2 5 3
#  2 5 2 2 0 2 2 2 0 5 5 5 5 0 5 4 2 2 5 2 0 2 5 2 5 2 5 0 0 5 2 2 2 0 2 0 5
#  3 0 0 2 2 5 5 5 0 0 2 0 3 2 2 5 0 5 5 2 5 2 2 5 0 0 5 1 5 3 2 0 0 5 5 2 0
#  2 0 2 5 0 0 3 5 2 0 5 2 5 5 3 2 5 5 2 5 5 1 2 3 2 0 0 2 4 5 0 5 2 4 0 5 2
#  5 5 4 2 5 3 5 5 1 4 5 2 2 5 0 2 0 2 5 2 5 5 2 2 4 5 2 2 0 0 0 2 0 0 4 2 2
#  5 2 2 2 2 5 5 0 5 5 4 2 0 2 2 0 1 0 2 2 2 2 1 0 2 1 3 2 5 5 2 0 0 2 3 5 2
#  2 5 2 5 2 2 5 0 0 0 2 2 5 5 2 2 5 2 2 0 0 2 2 0 2 0 2 5 0 4 2 5 5 5 5 3 2
#  0 2 2 5 0 5 1 5 5 0 2 5 2 2 5 2 2 5 2 5 3 4 2 2 5 2 2 2 5 2 2 2 5 2 0 0 2
#  0 5 2 3 5 2 2 0 2 3 2 2 3]
# /tmp/ipykernel_2264898/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# ### What features did the model use to make decisions?
#
# Based on the confusion matrices and validation loss, it is clear that the model is learning. To determine the features that are involved in decision making, there are a few possible approaches. One options is shown below, integrated gradients.

# %% [markdown]
# #### Understanding feature importance using Integrated Gradients
#
# <font color='green'>Integrated gradients is an attribution method. Attribution methods score the input data based on the prediction that the model makes using scores for each feature. The gradient is the signal that tells the network how much to increase or decrease a certain weight in the network during backpropogation. These gradients are overlaid onto the images to showcase the regions on the images that influence the weights.
#
# Run the below code.

# %%
def visualize_ig(idx, 
                 _train_dataset=train_set, 
                 _test_dataset=test_set):
        
    # Get corresponding input and target tensors:
    input_tensor = _test_dataset[idx][0].unsqueeze(0)
    input_tensor.requires_grad = True
    target = _test_dataset[idx][1]
    
    # We will use the IntegratedGradients algorithm:
    algorithm = IntegratedGradients(model)
    
    # First we clear the gradients from the model:
    model.zero_grad()
    
    # Run attribution:
    attr_ig, delta = algorithm.attribute(input_tensor,
                                          target=target,
                                          baselines=input_tensor * 0,
                                          return_convergence_delta=True
                                        )
    
    # Integrated Gradients:
    attr_ig = np.transpose(attr_ig[0].cpu().detach().numpy(), (1, 2, 0))
    
    # Original image:
    original_image = np.transpose((_test_dataset[idx][0].detach().numpy() * 0.5) + 0.5, (1, 2, 0))
    
    print("Annotated whale species", test_true[idx])
    plt.imshow(original_image)
    
    
    print("Predicted whale species", test_pred[idx])


    # This visualises the attribution of labels to 
    viz.visualize_image_attr(attr_ig, 
                             original_image, 
                             method="blended_heat_map",
                             sign="all",
                             show_colorbar=True, 
                             title="Overlayed Integrated Gradients")

test_pred, test_true = predict(model, test_set)

visualize_ig(0)
visualize_ig(8)
visualize_ig(20)
visualize_ig(32)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.3020807..1.6369936].
# Annotated whale species 5
# Predicted whale species 5
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.38770443..1.7589979].
# Annotated whale species 5
# Predicted whale species 2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.44764107..1.0792594].
# Annotated whale species 2
# Predicted whale species 2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5075778..1.82].
# Annotated whale species 2
# Predicted whale species 2

# %% [markdown]
# <font color='magenta'>Does the integrated gradient show what types of features the model used to classify the images? Do you notice any potential problems? (2 pts)

# %% [markdown]
# You can see tracings of features that the model is using to classify the images. The fins and back shapes of the whales are highlighted, but a lot ripples and splashes in the water are highlighted too, which are not related the whales themselves.

# %% [markdown]
# ## Part 2
#
# Now that you have a sense for how to train a machine learning model, your task is to improve the success of our classification model.
#
# **In three separate training events, make one (or more) modifications to the model training process, re-train the model, and report out your changes and whether they increased model accuracy. Why did you chose your particular change (curiousity, hypothesis, ect.)? Do you have ideas why your modifications were/were not successful?**
#
# Types of changes that you can make include:
# - [Using the pre-trained weights for ResNet18 (transfer learning)](https://docs.pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - Changing hyperparameters (learning rate, batch size)
# - [Changing transformation approach](https://docs.pytorch.org/vision/0.11/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py)
# - [Changing the optimizer](https://docs.pytorch.org/docs/stable/optim.html)
# - [Changing the model to a different pre-made model architecture](https://docs.pytorch.org/vision/main/models.html)
# - Modifying the ResNet18 model
# - Coming up with a whole new model!
#
# If you decide to change any lines of code that are not in the below box, please add them to the box (DO NOT MODIFY ANY CODE ABOVE THIS MARKDOWN BOX - IT MAY BREAK PART 1).
#
# If your changes are ambitious, the code may take hours to run. If this is the case, please consider turning this notebook into a python script and running it via sBATCH.
#
# **Please note, you will NOT be graded by the success of your classifiers! It is okay if you are unable to improve the accuracy of the classifier**

# %% [markdown]
# #### Your Model 1 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# I am trying to lower the learning rate to 1e-4. The learning accuracy is maxing out around 75% so maybe lowering the rate will allow it to become a little more refined. If it has slower progress that won't be an issue since it is maxing out. I am going to try the AdamW optimizer with this as well to check it out. Based on research it seems like AdamW with the added weight decay hyperparameter is good for smaller datasets.

# %%
batchsize = 48
learning_rate=1e-4
weight_decay=1e-2
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay = weight_decay)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod1", ##update this with your name
    config={"learning rate":1e-4, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(resnet18_model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/rmurnane/.netrc.
# wandb: Currently logged in as: urmom69swag (BGMP_HappyWhale) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/rmurnane/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_202651-dza5151o</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/dza5151o' target="_blank">Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod1</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/dza5151o' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/dza5151o</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 8.33%
# Epoch [1/5] | Batch #2 | Batch Accuracy 21.88%
# Epoch [1/5] | Batch #3 | Batch Accuracy 34.72%
# Epoch [1/5] | Batch #4 | Batch Accuracy 39.06%
# Epoch [1/5] | Batch #5 | Batch Accuracy 43.33%
# Epoch [1/5] | Batch #6 | Batch Accuracy 47.57%
# Epoch [1/5] | Batch #7 | Batch Accuracy 49.70%
# Epoch [1/5] | Batch #8 | Batch Accuracy 51.30%
# Epoch [1/5] | Batch #9 | Batch Accuracy 53.70%
# Epoch [1/5] | Batch #10 | Batch Accuracy 55.42%
# Epoch [1/5] | Batch #11 | Batch Accuracy 55.49%
# Epoch [1/5] | Batch #12 | Batch Accuracy 56.60%
# Epoch [1/5] | Batch #13 | Batch Accuracy 57.05%
# Epoch [1/5] | Batch #14 | Batch Accuracy 57.74%
# Epoch [1/5] | Batch #15 | Batch Accuracy 58.19%
# Epoch [1/5] | Batch #16 | Batch Accuracy 58.33%
# Epoch [1/5] | Batch #17 | Batch Accuracy 59.07%
# Epoch [1/5] | Batch #18 | Batch Accuracy 59.61%
# Epoch [1/5] | Batch #19 | Batch Accuracy 59.43%
# Epoch [1/5] | Batch #20 | Batch Accuracy 60.21%
# Epoch [1/5] | Batch #21 | Batch Accuracy 61.61%
# Epoch [1/5] | Batch #22 | Batch Accuracy 61.55%
# Epoch [1/5] | Batch #23 | Batch Accuracy 61.59%
# Epoch [1/5] | Batch #24 | Batch Accuracy 61.89%
# Epoch [1/5] | Batch #25 | Batch Accuracy 62.17%
# Epoch [1/5] | Batch #26 | Batch Accuracy 62.90%
# Epoch [1/5] | Batch #27 | Batch Accuracy 62.96%
# Epoch [1/5] | Batch #28 | Batch Accuracy 63.24%
# Epoch [1/5] | Batch #29 | Batch Accuracy 63.86%
# Epoch [1/5] | Batch #30 | Batch Accuracy 64.24%
# Epoch [1/5] | Batch #31 | Batch Accuracy 64.72%
# Epoch [1/5] | Batch #32 | Batch Accuracy 65.17%
# Epoch [1/5] | Batch #33 | Batch Accuracy 65.28%
# Epoch [1/5] | Batch #34 | Batch Accuracy 65.26%
# Epoch [1/5] | Batch #35 | Batch Accuracy 65.42%
# Epoch [1/5] | Batch #36 | Batch Accuracy 65.34%
# Epoch [1/5] | Batch #37 | Batch Accuracy 65.54%
# Epoch [1/5] | Batch #38 | Batch Accuracy 65.84%
# Epoch [1/5] | Batch #39 | Batch Accuracy 65.87%
# Epoch [1/5] | Batch #40 | Batch Accuracy 65.94%
# Epoch [1/5] Train Loss: 0.9532 | Train Acc: 65.94% | Val Acc: 54.43% | Val Loss: 1.11%
# Epoch [2/5] | Batch #41 | Batch Accuracy 66.67%
# Epoch [2/5] | Batch #42 | Batch Accuracy 70.83%
# Epoch [2/5] | Batch #43 | Batch Accuracy 69.44%
# Epoch [2/5] | Batch #44 | Batch Accuracy 71.88%
# Epoch [2/5] | Batch #45 | Batch Accuracy 72.92%
# Epoch [2/5] | Batch #46 | Batch Accuracy 73.26%
# Epoch [2/5] | Batch #47 | Batch Accuracy 72.92%
# Epoch [2/5] | Batch #48 | Batch Accuracy 71.88%
# Epoch [2/5] | Batch #49 | Batch Accuracy 72.22%
# Epoch [2/5] | Batch #50 | Batch Accuracy 72.71%
# Epoch [2/5] | Batch #51 | Batch Accuracy 73.48%
# Epoch [2/5] | Batch #52 | Batch Accuracy 73.96%
# Epoch [2/5] | Batch #53 | Batch Accuracy 73.72%
# Epoch [2/5] | Batch #54 | Batch Accuracy 74.11%
# Epoch [2/5] | Batch #55 | Batch Accuracy 73.75%
# Epoch [2/5] | Batch #56 | Batch Accuracy 74.22%
# Epoch [2/5] | Batch #57 | Batch Accuracy 74.39%
# Epoch [2/5] | Batch #58 | Batch Accuracy 74.42%
# Epoch [2/5] | Batch #59 | Batch Accuracy 74.78%
# Epoch [2/5] | Batch #60 | Batch Accuracy 75.31%
# Epoch [2/5] | Batch #61 | Batch Accuracy 75.20%
# Epoch [2/5] | Batch #62 | Batch Accuracy 75.28%
# Epoch [2/5] | Batch #63 | Batch Accuracy 75.27%
# Epoch [2/5] | Batch #64 | Batch Accuracy 75.78%
# Epoch [2/5] | Batch #65 | Batch Accuracy 75.83%
# Epoch [2/5] | Batch #66 | Batch Accuracy 75.56%
# Epoch [2/5] | Batch #67 | Batch Accuracy 75.85%
# Epoch [2/5] | Batch #68 | Batch Accuracy 76.41%
# Epoch [2/5] | Batch #69 | Batch Accuracy 76.72%
# Epoch [2/5] | Batch #70 | Batch Accuracy 76.67%
# Epoch [2/5] | Batch #71 | Batch Accuracy 76.61%
# Epoch [2/5] | Batch #72 | Batch Accuracy 76.69%
# Epoch [2/5] | Batch #73 | Batch Accuracy 76.70%
# Epoch [2/5] | Batch #74 | Batch Accuracy 76.78%
# Epoch [2/5] | Batch #75 | Batch Accuracy 76.73%
# Epoch [2/5] | Batch #76 | Batch Accuracy 76.74%
# Epoch [2/5] | Batch #77 | Batch Accuracy 77.03%
# Epoch [2/5] | Batch #78 | Batch Accuracy 76.97%
# Epoch [2/5] | Batch #79 | Batch Accuracy 77.03%
# Epoch [2/5] | Batch #80 | Batch Accuracy 77.29%
# Epoch [2/5] Train Loss: 0.6465 | Train Acc: 77.29% | Val Acc: 47.92% | Val Loss: 2.07%
# Epoch [3/5] | Batch #81 | Batch Accuracy 70.83%
# Epoch [3/5] | Batch #82 | Batch Accuracy 76.04%
# Epoch [3/5] | Batch #83 | Batch Accuracy 77.08%
# Epoch [3/5] | Batch #84 | Batch Accuracy 78.12%
# Epoch [3/5] | Batch #85 | Batch Accuracy 75.42%
# Epoch [3/5] | Batch #86 | Batch Accuracy 76.74%
# Epoch [3/5] | Batch #87 | Batch Accuracy 75.89%
# Epoch [3/5] | Batch #88 | Batch Accuracy 76.04%
# Epoch [3/5] | Batch #89 | Batch Accuracy 75.23%
# Epoch [3/5] | Batch #90 | Batch Accuracy 75.62%
# Epoch [3/5] | Batch #91 | Batch Accuracy 75.57%
# Epoch [3/5] | Batch #92 | Batch Accuracy 75.17%
# Epoch [3/5] | Batch #93 | Batch Accuracy 75.00%
# Epoch [3/5] | Batch #94 | Batch Accuracy 74.85%
# Epoch [3/5] | Batch #95 | Batch Accuracy 74.72%
# Epoch [3/5] | Batch #96 | Batch Accuracy 75.13%
# Epoch [3/5] | Batch #97 | Batch Accuracy 75.74%
# Epoch [3/5] | Batch #98 | Batch Accuracy 75.81%
# Epoch [3/5] | Batch #99 | Batch Accuracy 75.77%
# Epoch [3/5] | Batch #100 | Batch Accuracy 76.25%
# Epoch [3/5] | Batch #101 | Batch Accuracy 75.89%
# Epoch [3/5] | Batch #102 | Batch Accuracy 75.76%
# Epoch [3/5] | Batch #103 | Batch Accuracy 76.27%
# Epoch [3/5] | Batch #104 | Batch Accuracy 76.56%
# Epoch [3/5] | Batch #105 | Batch Accuracy 76.08%
# Epoch [3/5] | Batch #106 | Batch Accuracy 76.44%
# Epoch [3/5] | Batch #107 | Batch Accuracy 76.39%
# Epoch [3/5] | Batch #108 | Batch Accuracy 76.49%
# Epoch [3/5] | Batch #109 | Batch Accuracy 76.36%
# Epoch [3/5] | Batch #110 | Batch Accuracy 76.39%
# Epoch [3/5] | Batch #111 | Batch Accuracy 76.48%
# Epoch [3/5] | Batch #112 | Batch Accuracy 76.76%
# Epoch [3/5] | Batch #113 | Batch Accuracy 76.83%
# Epoch [3/5] | Batch #114 | Batch Accuracy 76.78%
# Epoch [3/5] | Batch #115 | Batch Accuracy 77.14%
# Epoch [3/5] | Batch #116 | Batch Accuracy 76.97%
# Epoch [3/5] | Batch #117 | Batch Accuracy 76.69%
# Epoch [3/5] | Batch #118 | Batch Accuracy 76.70%
# Epoch [3/5] | Batch #119 | Batch Accuracy 76.87%
# Epoch [3/5] | Batch #120 | Batch Accuracy 76.93%
# Epoch [3/5] Train Loss: 0.6237 | Train Acc: 76.93% | Val Acc: 76.82% | Val Loss: 0.73%
# Epoch [4/5] | Batch #121 | Batch Accuracy 79.17%
# Epoch [4/5] | Batch #122 | Batch Accuracy 83.33%
# Epoch [4/5] | Batch #123 | Batch Accuracy 82.64%
# Epoch [4/5] | Batch #124 | Batch Accuracy 81.25%
# Epoch [4/5] | Batch #125 | Batch Accuracy 80.42%
# Epoch [4/5] | Batch #126 | Batch Accuracy 80.90%
# Epoch [4/5] | Batch #127 | Batch Accuracy 80.95%
# Epoch [4/5] | Batch #128 | Batch Accuracy 80.73%
# Epoch [4/5] | Batch #129 | Batch Accuracy 79.63%
# Epoch [4/5] | Batch #130 | Batch Accuracy 79.38%
# Epoch [4/5] | Batch #131 | Batch Accuracy 79.73%
# Epoch [4/5] | Batch #132 | Batch Accuracy 79.69%
# Epoch [4/5] | Batch #133 | Batch Accuracy 80.29%
# Epoch [4/5] | Batch #134 | Batch Accuracy 79.91%
# Epoch [4/5] | Batch #135 | Batch Accuracy 80.42%
# Epoch [4/5] | Batch #136 | Batch Accuracy 80.08%
# Epoch [4/5] | Batch #137 | Batch Accuracy 80.39%
# Epoch [4/5] | Batch #138 | Batch Accuracy 80.32%
# Epoch [4/5] | Batch #139 | Batch Accuracy 80.48%
# Epoch [4/5] | Batch #140 | Batch Accuracy 80.42%
# Epoch [4/5] | Batch #141 | Batch Accuracy 80.36%
# Epoch [4/5] | Batch #142 | Batch Accuracy 80.21%
# Epoch [4/5] | Batch #143 | Batch Accuracy 80.07%
# Epoch [4/5] | Batch #144 | Batch Accuracy 80.56%
# Epoch [4/5] | Batch #145 | Batch Accuracy 80.33%
# Epoch [4/5] | Batch #146 | Batch Accuracy 80.21%
# Epoch [4/5] | Batch #147 | Batch Accuracy 80.17%
# Epoch [4/5] | Batch #148 | Batch Accuracy 80.13%
# Epoch [4/5] | Batch #149 | Batch Accuracy 79.89%
# Epoch [4/5] | Batch #150 | Batch Accuracy 80.07%
# Epoch [4/5] | Batch #151 | Batch Accuracy 80.17%
# Epoch [4/5] | Batch #152 | Batch Accuracy 80.14%
# Epoch [4/5] | Batch #153 | Batch Accuracy 80.43%
# Epoch [4/5] | Batch #154 | Batch Accuracy 80.58%
# Epoch [4/5] | Batch #155 | Batch Accuracy 80.36%
# Epoch [4/5] | Batch #156 | Batch Accuracy 80.27%
# Epoch [4/5] | Batch #157 | Batch Accuracy 80.18%
# Epoch [4/5] | Batch #158 | Batch Accuracy 80.26%
# Epoch [4/5] | Batch #159 | Batch Accuracy 79.97%
# Epoch [4/5] | Batch #160 | Batch Accuracy 79.90%
# Epoch [4/5] Train Loss: 0.5455 | Train Acc: 79.90% | Val Acc: 68.49% | Val Loss: 0.76%
# Epoch [5/5] | Batch #161 | Batch Accuracy 79.17%
# Epoch [5/5] | Batch #162 | Batch Accuracy 82.29%
# Epoch [5/5] | Batch #163 | Batch Accuracy 85.42%
# Epoch [5/5] | Batch #164 | Batch Accuracy 85.94%
# Epoch [5/5] | Batch #165 | Batch Accuracy 85.42%
# Epoch [5/5] | Batch #166 | Batch Accuracy 85.76%
# Epoch [5/5] | Batch #167 | Batch Accuracy 84.82%
# Epoch [5/5] | Batch #168 | Batch Accuracy 83.85%
# Epoch [5/5] | Batch #169 | Batch Accuracy 83.80%
# Epoch [5/5] | Batch #170 | Batch Accuracy 84.17%
# Epoch [5/5] | Batch #171 | Batch Accuracy 84.85%
# Epoch [5/5] | Batch #172 | Batch Accuracy 84.90%
# Epoch [5/5] | Batch #173 | Batch Accuracy 85.26%
# Epoch [5/5] | Batch #174 | Batch Accuracy 84.97%
# Epoch [5/5] | Batch #175 | Batch Accuracy 85.00%
# Epoch [5/5] | Batch #176 | Batch Accuracy 85.16%
# Epoch [5/5] | Batch #177 | Batch Accuracy 85.29%
# Epoch [5/5] | Batch #178 | Batch Accuracy 84.61%
# Epoch [5/5] | Batch #179 | Batch Accuracy 84.76%
# Epoch [5/5] | Batch #180 | Batch Accuracy 84.38%
# Epoch [5/5] | Batch #181 | Batch Accuracy 84.23%
# Epoch [5/5] | Batch #182 | Batch Accuracy 84.19%
# Epoch [5/5] | Batch #183 | Batch Accuracy 83.97%
# Epoch [5/5] | Batch #184 | Batch Accuracy 83.85%
# Epoch [5/5] | Batch #185 | Batch Accuracy 84.00%
# Epoch [5/5] | Batch #186 | Batch Accuracy 83.89%
# Epoch [5/5] | Batch #187 | Batch Accuracy 83.72%
# Epoch [5/5] | Batch #188 | Batch Accuracy 83.71%
# Epoch [5/5] | Batch #189 | Batch Accuracy 83.69%
# Epoch [5/5] | Batch #190 | Batch Accuracy 83.89%
# Epoch [5/5] | Batch #191 | Batch Accuracy 83.94%
# Epoch [5/5] | Batch #192 | Batch Accuracy 84.05%
# Epoch [5/5] | Batch #193 | Batch Accuracy 83.84%
# Epoch [5/5] | Batch #194 | Batch Accuracy 83.52%
# Epoch [5/5] | Batch #195 | Batch Accuracy 83.39%
# Epoch [5/5] | Batch #196 | Batch Accuracy 83.62%
# Epoch [5/5] | Batch #197 | Batch Accuracy 83.73%
# Epoch [5/5] | Batch #198 | Batch Accuracy 83.72%
# Epoch [5/5] | Batch #199 | Batch Accuracy 83.65%
# Epoch [5/5] | Batch #200 | Batch Accuracy 83.59%
# Epoch [5/5] Train Loss: 0.4461 | Train Acc: 83.59% | Val Acc: 78.65% | Val Loss: 0.62%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>validation_accuracy</td><td>▂▁█▆█</td></tr><tr><td>validation_loss</td><td>▃█▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.44608</td></tr><tr><td>validation_accuracy</td><td>78.64583</td></tr><tr><td>validation_loss</td><td>0.62482</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod1</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/dza5151o' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/dza5151o</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_202651-dza5151o/logs</code>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 88
#      84     wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})
#      86 wandb.finish()
# ---> 88 plt.plot(range(epochs), validation_accuracy_list, color = "magenta")
#      89 plt.xlabel("Epoch number")
#      90 plt.ylabel("Valiation accuracy")
#
# NameError: name 'validation_accuracy_list' is not defined

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       8 plt.ylabel("Valiation loss")
#       9 plt.show()
# ---> 11 y_pred, y_true = predict(resnet18_model, test_set)
#      12 cm_analysis(y_true, y_pred, "Confusion matrix")
#
# NameError: name 'predict' is not defined

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

## This plot only contains the test set of data
## The test set of data has not been seen by the model yet
# y_pred, y_true = predict(model, test_set)

# print(y_true)
# cm_analysis(y_true, y_pred, "Confusion matrix")

# y_pred, y_true = predict(model, test_set)
# cm_analysis(y_true, y_pred, "Confusion matrix")

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# The changes seem successful as the validation accuracy rose all the way to 78.65%. It seems like based on the size of the data perhaps that a slower learning rate was good or the optimizer was a better fit.

# %% [markdown]
# #### Your Model 2 (10pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# I am changing the model to the pretrained resnet18 and setting it to 6 outputs. According to the documentation this should have the weights already trained for image data and thus be easier to train with the whales. I am also lowering the batch size to 32 from 48. Since the dataset is small, this will give it more chances to train on each batch and could help randomize the batches more.

# %%
batchsize = 32
learning_rate=1e-4
weight_decay=1e-2
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
model = torchvision.models.resnet18(weights = "IMAGENET1K_V1").to(device)
model.fc = nn.Linear(model.fc.in_features, 6)
#model = torchvision.models.resnet18(weights = "IMAGENET1K_V1", progress  = True).to(device)
#resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay = weight_decay)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod2", ##update this with your name
    config={"learning rate":1e-4, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":32}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/rmurnane/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_231404-p873npdt</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/p873npdt' target="_blank">Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod2</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/p873npdt' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/p873npdt</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 12.50%
# Epoch [1/5] | Batch #2 | Batch Accuracy 12.50%
# Epoch [1/5] | Batch #3 | Batch Accuracy 27.08%
# Epoch [1/5] | Batch #4 | Batch Accuracy 39.06%
# Epoch [1/5] | Batch #5 | Batch Accuracy 46.25%
# Epoch [1/5] | Batch #6 | Batch Accuracy 49.48%
# Epoch [1/5] | Batch #7 | Batch Accuracy 55.36%
# Epoch [1/5] | Batch #8 | Batch Accuracy 57.81%
# Epoch [1/5] | Batch #9 | Batch Accuracy 60.76%
# Epoch [1/5] | Batch #10 | Batch Accuracy 62.50%
# Epoch [1/5] | Batch #11 | Batch Accuracy 65.06%
# Epoch [1/5] | Batch #12 | Batch Accuracy 66.93%
# Epoch [1/5] | Batch #13 | Batch Accuracy 68.75%
# Epoch [1/5] | Batch #14 | Batch Accuracy 70.76%
# Epoch [1/5] | Batch #15 | Batch Accuracy 72.50%
# Epoch [1/5] | Batch #16 | Batch Accuracy 74.02%
# Epoch [1/5] | Batch #17 | Batch Accuracy 74.82%
# Epoch [1/5] | Batch #18 | Batch Accuracy 75.87%
# Epoch [1/5] | Batch #19 | Batch Accuracy 76.32%
# Epoch [1/5] | Batch #20 | Batch Accuracy 77.34%
# Epoch [1/5] | Batch #21 | Batch Accuracy 77.98%
# Epoch [1/5] | Batch #22 | Batch Accuracy 78.27%
# Epoch [1/5] | Batch #23 | Batch Accuracy 78.80%
# Epoch [1/5] | Batch #24 | Batch Accuracy 79.69%
# Epoch [1/5] | Batch #25 | Batch Accuracy 80.25%
# Epoch [1/5] | Batch #26 | Batch Accuracy 81.01%
# Epoch [1/5] | Batch #27 | Batch Accuracy 81.48%
# Epoch [1/5] | Batch #28 | Batch Accuracy 81.92%
# Epoch [1/5] | Batch #29 | Batch Accuracy 82.11%
# Epoch [1/5] | Batch #30 | Batch Accuracy 82.60%
# Epoch [1/5] | Batch #31 | Batch Accuracy 83.06%
# Epoch [1/5] | Batch #32 | Batch Accuracy 83.50%
# Epoch [1/5] | Batch #33 | Batch Accuracy 83.90%
# Epoch [1/5] | Batch #34 | Batch Accuracy 84.38%
# Epoch [1/5] | Batch #35 | Batch Accuracy 84.73%
# Epoch [1/5] | Batch #36 | Batch Accuracy 85.07%
# Epoch [1/5] | Batch #37 | Batch Accuracy 85.30%
# Epoch [1/5] | Batch #38 | Batch Accuracy 85.69%
# Epoch [1/5] | Batch #39 | Batch Accuracy 85.90%
# Epoch [1/5] | Batch #40 | Batch Accuracy 86.17%
# Epoch [1/5] | Batch #41 | Batch Accuracy 86.36%
# Epoch [1/5] | Batch #42 | Batch Accuracy 86.61%
# Epoch [1/5] | Batch #43 | Batch Accuracy 86.77%
# Epoch [1/5] | Batch #44 | Batch Accuracy 87.00%
# Epoch [1/5] | Batch #45 | Batch Accuracy 87.29%
# Epoch [1/5] | Batch #46 | Batch Accuracy 87.43%
# Epoch [1/5] | Batch #47 | Batch Accuracy 87.50%
# Epoch [1/5] | Batch #48 | Batch Accuracy 87.70%
# Epoch [1/5] | Batch #49 | Batch Accuracy 87.95%
# Epoch [1/5] | Batch #50 | Batch Accuracy 88.19%
# Epoch [1/5] | Batch #51 | Batch Accuracy 88.36%
# Epoch [1/5] | Batch #52 | Batch Accuracy 88.52%
# Epoch [1/5] | Batch #53 | Batch Accuracy 88.68%
# Epoch [1/5] | Batch #54 | Batch Accuracy 88.83%
# Epoch [1/5] | Batch #55 | Batch Accuracy 89.03%
# Epoch [1/5] | Batch #56 | Batch Accuracy 89.23%
# Epoch [1/5] | Batch #57 | Batch Accuracy 89.36%
# Epoch [1/5] | Batch #58 | Batch Accuracy 89.55%
# Epoch [1/5] | Batch #59 | Batch Accuracy 89.62%
# Epoch [1/5] | Batch #60 | Batch Accuracy 89.64%
# Epoch [1/5] | Batch #61 | Batch Accuracy 89.81%
# Epoch [1/5] Train Loss: 0.3480 | Train Acc: 89.81% | Val Acc: 98.32% | Val Loss: 0.10%
# Epoch [2/5] | Batch #62 | Batch Accuracy 96.88%
# Epoch [2/5] | Batch #63 | Batch Accuracy 96.88%
# Epoch [2/5] | Batch #64 | Batch Accuracy 97.92%
# Epoch [2/5] | Batch #65 | Batch Accuracy 97.66%
# Epoch [2/5] | Batch #66 | Batch Accuracy 97.50%
# Epoch [2/5] | Batch #67 | Batch Accuracy 97.92%
# Epoch [2/5] | Batch #68 | Batch Accuracy 98.21%
# Epoch [2/5] | Batch #69 | Batch Accuracy 98.44%
# Epoch [2/5] | Batch #70 | Batch Accuracy 98.61%
# Epoch [2/5] | Batch #71 | Batch Accuracy 98.12%
# Epoch [2/5] | Batch #72 | Batch Accuracy 98.30%
# Epoch [2/5] | Batch #73 | Batch Accuracy 98.44%
# Epoch [2/5] | Batch #74 | Batch Accuracy 98.32%
# Epoch [2/5] | Batch #75 | Batch Accuracy 97.99%
# Epoch [2/5] | Batch #76 | Batch Accuracy 97.71%
# Epoch [2/5] | Batch #77 | Batch Accuracy 97.85%
# Epoch [2/5] | Batch #78 | Batch Accuracy 97.98%
# Epoch [2/5] | Batch #79 | Batch Accuracy 98.09%
# Epoch [2/5] | Batch #80 | Batch Accuracy 98.19%
# Epoch [2/5] | Batch #81 | Batch Accuracy 98.28%
# Epoch [2/5] | Batch #82 | Batch Accuracy 98.07%
# Epoch [2/5] | Batch #83 | Batch Accuracy 98.15%
# Epoch [2/5] | Batch #84 | Batch Accuracy 98.10%
# Epoch [2/5] | Batch #85 | Batch Accuracy 98.18%
# Epoch [2/5] | Batch #86 | Batch Accuracy 98.25%
# Epoch [2/5] | Batch #87 | Batch Accuracy 98.32%
# Epoch [2/5] | Batch #88 | Batch Accuracy 98.38%
# Epoch [2/5] | Batch #89 | Batch Accuracy 98.44%
# Epoch [2/5] | Batch #90 | Batch Accuracy 98.49%
# Epoch [2/5] | Batch #91 | Batch Accuracy 98.54%
# Epoch [2/5] | Batch #92 | Batch Accuracy 98.39%
# Epoch [2/5] | Batch #93 | Batch Accuracy 98.44%
# Epoch [2/5] | Batch #94 | Batch Accuracy 98.39%
# Epoch [2/5] | Batch #95 | Batch Accuracy 98.44%
# Epoch [2/5] | Batch #96 | Batch Accuracy 98.48%
# Epoch [2/5] | Batch #97 | Batch Accuracy 98.52%
# Epoch [2/5] | Batch #98 | Batch Accuracy 98.56%
# Epoch [2/5] | Batch #99 | Batch Accuracy 98.60%
# Epoch [2/5] | Batch #100 | Batch Accuracy 98.64%
# Epoch [2/5] | Batch #101 | Batch Accuracy 98.67%
# Epoch [2/5] | Batch #102 | Batch Accuracy 98.70%
# Epoch [2/5] | Batch #103 | Batch Accuracy 98.74%
# Epoch [2/5] | Batch #104 | Batch Accuracy 98.76%
# Epoch [2/5] | Batch #105 | Batch Accuracy 98.79%
# Epoch [2/5] | Batch #106 | Batch Accuracy 98.82%
# Epoch [2/5] | Batch #107 | Batch Accuracy 98.85%
# Epoch [2/5] | Batch #108 | Batch Accuracy 98.87%
# Epoch [2/5] | Batch #109 | Batch Accuracy 98.89%
# Epoch [2/5] | Batch #110 | Batch Accuracy 98.92%
# Epoch [2/5] | Batch #111 | Batch Accuracy 98.88%
# Epoch [2/5] | Batch #112 | Batch Accuracy 98.90%
# Epoch [2/5] | Batch #113 | Batch Accuracy 98.92%
# Epoch [2/5] | Batch #114 | Batch Accuracy 98.94%
# Epoch [2/5] | Batch #115 | Batch Accuracy 98.96%
# Epoch [2/5] | Batch #116 | Batch Accuracy 98.98%
# Epoch [2/5] | Batch #117 | Batch Accuracy 99.00%
# Epoch [2/5] | Batch #118 | Batch Accuracy 99.01%
# Epoch [2/5] | Batch #119 | Batch Accuracy 99.03%
# Epoch [2/5] | Batch #120 | Batch Accuracy 98.99%
# Epoch [2/5] | Batch #121 | Batch Accuracy 98.91%
# Epoch [2/5] | Batch #122 | Batch Accuracy 98.92%
# Epoch [2/5] Train Loss: 0.0524 | Train Acc: 98.92% | Val Acc: 97.84% | Val Loss: 0.09%
# Epoch [3/5] | Batch #123 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #124 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #125 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #126 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #127 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #128 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #129 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #130 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #131 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #132 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #133 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #134 | Batch Accuracy 99.74%
# Epoch [3/5] | Batch #135 | Batch Accuracy 99.76%
# Epoch [3/5] | Batch #136 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #137 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #138 | Batch Accuracy 99.61%
# Epoch [3/5] | Batch #139 | Batch Accuracy 99.63%
# Epoch [3/5] | Batch #140 | Batch Accuracy 99.65%
# Epoch [3/5] | Batch #141 | Batch Accuracy 99.67%
# Epoch [3/5] | Batch #142 | Batch Accuracy 99.69%
# Epoch [3/5] | Batch #143 | Batch Accuracy 99.70%
# Epoch [3/5] | Batch #144 | Batch Accuracy 99.72%
# Epoch [3/5] | Batch #145 | Batch Accuracy 99.73%
# Epoch [3/5] | Batch #146 | Batch Accuracy 99.74%
# Epoch [3/5] | Batch #147 | Batch Accuracy 99.75%
# Epoch [3/5] | Batch #148 | Batch Accuracy 99.76%
# Epoch [3/5] | Batch #149 | Batch Accuracy 99.77%
# Epoch [3/5] | Batch #150 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #151 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #152 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #153 | Batch Accuracy 99.80%
# Epoch [3/5] | Batch #154 | Batch Accuracy 99.80%
# Epoch [3/5] | Batch #155 | Batch Accuracy 99.81%
# Epoch [3/5] | Batch #156 | Batch Accuracy 99.82%
# Epoch [3/5] | Batch #157 | Batch Accuracy 99.82%
# Epoch [3/5] | Batch #158 | Batch Accuracy 99.83%
# Epoch [3/5] | Batch #159 | Batch Accuracy 99.83%
# Epoch [3/5] | Batch #160 | Batch Accuracy 99.84%
# Epoch [3/5] | Batch #161 | Batch Accuracy 99.84%
# Epoch [3/5] | Batch #162 | Batch Accuracy 99.84%
# Epoch [3/5] | Batch #163 | Batch Accuracy 99.85%
# Epoch [3/5] | Batch #164 | Batch Accuracy 99.85%
# Epoch [3/5] | Batch #165 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #166 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #167 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #168 | Batch Accuracy 99.80%
# Epoch [3/5] | Batch #169 | Batch Accuracy 99.80%
# Epoch [3/5] | Batch #170 | Batch Accuracy 99.80%
# Epoch [3/5] | Batch #171 | Batch Accuracy 99.81%
# Epoch [3/5] | Batch #172 | Batch Accuracy 99.81%
# Epoch [3/5] | Batch #173 | Batch Accuracy 99.82%
# Epoch [3/5] | Batch #174 | Batch Accuracy 99.82%
# Epoch [3/5] | Batch #175 | Batch Accuracy 99.82%
# Epoch [3/5] | Batch #176 | Batch Accuracy 99.83%
# Epoch [3/5] | Batch #177 | Batch Accuracy 99.77%
# Epoch [3/5] | Batch #178 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #179 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #180 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #181 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #182 | Batch Accuracy 99.74%
# Epoch [3/5] | Batch #183 | Batch Accuracy 99.74%
# Epoch [3/5] Train Loss: 0.0202 | Train Acc: 99.74% | Val Acc: 98.32% | Val Loss: 0.06%
# Epoch [4/5] | Batch #184 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #185 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #186 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #187 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #188 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #189 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #190 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #191 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #192 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #193 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #194 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #195 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #196 | Batch Accuracy 99.28%
# Epoch [4/5] | Batch #197 | Batch Accuracy 99.33%
# Epoch [4/5] | Batch #198 | Batch Accuracy 99.38%
# Epoch [4/5] | Batch #199 | Batch Accuracy 99.41%
# Epoch [4/5] | Batch #200 | Batch Accuracy 99.45%
# Epoch [4/5] | Batch #201 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #202 | Batch Accuracy 99.34%
# Epoch [4/5] | Batch #203 | Batch Accuracy 99.38%
# Epoch [4/5] | Batch #204 | Batch Accuracy 99.40%
# Epoch [4/5] | Batch #205 | Batch Accuracy 99.43%
# Epoch [4/5] | Batch #206 | Batch Accuracy 99.46%
# Epoch [4/5] | Batch #207 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #208 | Batch Accuracy 99.50%
# Epoch [4/5] | Batch #209 | Batch Accuracy 99.52%
# Epoch [4/5] | Batch #210 | Batch Accuracy 99.54%
# Epoch [4/5] | Batch #211 | Batch Accuracy 99.44%
# Epoch [4/5] | Batch #212 | Batch Accuracy 99.46%
# Epoch [4/5] | Batch #213 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #214 | Batch Accuracy 99.40%
# Epoch [4/5] | Batch #215 | Batch Accuracy 99.32%
# Epoch [4/5] | Batch #216 | Batch Accuracy 99.24%
# Epoch [4/5] | Batch #217 | Batch Accuracy 99.26%
# Epoch [4/5] | Batch #218 | Batch Accuracy 99.29%
# Epoch [4/5] | Batch #219 | Batch Accuracy 99.31%
# Epoch [4/5] | Batch #220 | Batch Accuracy 99.32%
# Epoch [4/5] | Batch #221 | Batch Accuracy 99.34%
# Epoch [4/5] | Batch #222 | Batch Accuracy 99.36%
# Epoch [4/5] | Batch #223 | Batch Accuracy 99.38%
# Epoch [4/5] | Batch #224 | Batch Accuracy 99.39%
# Epoch [4/5] | Batch #225 | Batch Accuracy 99.40%
# Epoch [4/5] | Batch #226 | Batch Accuracy 99.42%
# Epoch [4/5] | Batch #227 | Batch Accuracy 99.43%
# Epoch [4/5] | Batch #228 | Batch Accuracy 99.44%
# Epoch [4/5] | Batch #229 | Batch Accuracy 99.46%
# Epoch [4/5] | Batch #230 | Batch Accuracy 99.47%
# Epoch [4/5] | Batch #231 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #232 | Batch Accuracy 99.49%
# Epoch [4/5] | Batch #233 | Batch Accuracy 99.50%
# Epoch [4/5] | Batch #234 | Batch Accuracy 99.51%
# Epoch [4/5] | Batch #235 | Batch Accuracy 99.52%
# Epoch [4/5] | Batch #236 | Batch Accuracy 99.53%
# Epoch [4/5] | Batch #237 | Batch Accuracy 99.54%
# Epoch [4/5] | Batch #238 | Batch Accuracy 99.55%
# Epoch [4/5] | Batch #239 | Batch Accuracy 99.55%
# Epoch [4/5] | Batch #240 | Batch Accuracy 99.56%
# Epoch [4/5] | Batch #241 | Batch Accuracy 99.57%
# Epoch [4/5] | Batch #242 | Batch Accuracy 99.58%
# Epoch [4/5] | Batch #243 | Batch Accuracy 99.58%
# Epoch [4/5] | Batch #244 | Batch Accuracy 99.59%
# Epoch [4/5] Train Loss: 0.0211 | Train Acc: 99.59% | Val Acc: 98.08% | Val Loss: 0.07%
# Epoch [5/5] | Batch #245 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #246 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #247 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #248 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #249 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #250 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #251 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #252 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #253 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #254 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #255 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #256 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #257 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #258 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #259 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #260 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #261 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #262 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #263 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #264 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #265 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #266 | Batch Accuracy 99.86%
# Epoch [5/5] | Batch #267 | Batch Accuracy 99.86%
# Epoch [5/5] | Batch #268 | Batch Accuracy 99.87%
# Epoch [5/5] | Batch #269 | Batch Accuracy 99.88%
# Epoch [5/5] | Batch #270 | Batch Accuracy 99.88%
# Epoch [5/5] | Batch #271 | Batch Accuracy 99.88%
# Epoch [5/5] | Batch #272 | Batch Accuracy 99.89%
# Epoch [5/5] | Batch #273 | Batch Accuracy 99.78%
# Epoch [5/5] | Batch #274 | Batch Accuracy 99.79%
# Epoch [5/5] | Batch #275 | Batch Accuracy 99.80%
# Epoch [5/5] | Batch #276 | Batch Accuracy 99.71%
# Epoch [5/5] | Batch #277 | Batch Accuracy 99.72%
# Epoch [5/5] | Batch #278 | Batch Accuracy 99.72%
# Epoch [5/5] | Batch #279 | Batch Accuracy 99.73%
# Epoch [5/5] | Batch #280 | Batch Accuracy 99.74%
# Epoch [5/5] | Batch #281 | Batch Accuracy 99.75%
# Epoch [5/5] | Batch #282 | Batch Accuracy 99.67%
# Epoch [5/5] | Batch #283 | Batch Accuracy 99.68%
# Epoch [5/5] | Batch #284 | Batch Accuracy 99.69%
# Epoch [5/5] | Batch #285 | Batch Accuracy 99.62%
# Epoch [5/5] | Batch #286 | Batch Accuracy 99.63%
# Epoch [5/5] | Batch #287 | Batch Accuracy 99.64%
# Epoch [5/5] | Batch #288 | Batch Accuracy 99.64%
# Epoch [5/5] | Batch #289 | Batch Accuracy 99.65%
# Epoch [5/5] | Batch #290 | Batch Accuracy 99.66%
# Epoch [5/5] | Batch #291 | Batch Accuracy 99.67%
# Epoch [5/5] | Batch #292 | Batch Accuracy 99.67%
# Epoch [5/5] | Batch #293 | Batch Accuracy 99.68%
# Epoch [5/5] | Batch #294 | Batch Accuracy 99.69%
# Epoch [5/5] | Batch #295 | Batch Accuracy 99.69%
# Epoch [5/5] | Batch #296 | Batch Accuracy 99.70%
# Epoch [5/5] | Batch #297 | Batch Accuracy 99.71%
# Epoch [5/5] | Batch #298 | Batch Accuracy 99.71%
# Epoch [5/5] | Batch #299 | Batch Accuracy 99.72%
# Epoch [5/5] | Batch #300 | Batch Accuracy 99.61%
# Epoch [5/5] | Batch #301 | Batch Accuracy 99.62%
# Epoch [5/5] | Batch #302 | Batch Accuracy 99.57%
# Epoch [5/5] | Batch #303 | Batch Accuracy 99.58%
# Epoch [5/5] | Batch #304 | Batch Accuracy 99.58%
# Epoch [5/5] | Batch #305 | Batch Accuracy 99.59%
# Epoch [5/5] Train Loss: 0.0165 | Train Acc: 99.59% | Val Acc: 98.08% | Val Loss: 0.07%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▂▁▁▁</td></tr><tr><td>validation_accuracy</td><td>█▁█▄▄</td></tr><tr><td>validation_loss</td><td>█▆▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.01652</td></tr><tr><td>validation_accuracy</td><td>98.07692</td></tr><tr><td>validation_loss</td><td>0.06522</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod2</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/p873npdt' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/p873npdt</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_231404-p873npdt/logs</code>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 98
#      95 plt.ylabel("Valiation loss")
#      96 plt.show()
# ---> 98 y_pred, y_true = predict(model, test_set)
#      99 cm_analysis(y_true, y_pred, "Confusion matrix")
#
# NameError: name 'predict' is not defined

# %%
y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_2456973/2928404987.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# With 98.08% validation accuracy, the changes to the model this iteration drastically improved its performance. The model also ran a lot faster in 17 minutes compared to an hour and 20 minutes previously. It seems like preloading the weights in the model really affected the speed and the accuracy along with lowering the batch size. The predictions are all pretty close to 100% for each of the whale species except for the fin whale which seems to be a little more difficult to classify for some reason.

# %% [markdown]
# #### Your Model 3 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# The model was already very successful last round so I am going to try and update some of the data transformations and see. I am adding rotate and color jitter to see if they can help get rid of some of the random ocean pattern recognition that seems to pop up or might help classify the fin whales.

# %%
batchsize = 32
learning_rate=1e-4
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
model = torchvision.models.resnet18(weights = "IMAGENET1K_V1").to(device)
model.fc = nn.Linear(model.fc.in_features, 6)
#model = torchvision.models.resnet18(weights = "IMAGENET1K_V1", progress  = True).to(device)
#resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay = weight_decay)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod3", ##update this with your name
    config={"learning rate":1e-4, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":32}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), validation_accuracy_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), validation_loss_list, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/rmurnane/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_234813-yceh4zc7</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/yceh4zc7' target="_blank">Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod3</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/yceh4zc7' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/yceh4zc7</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 3.12%
# Epoch [1/5] | Batch #2 | Batch Accuracy 9.38%
# Epoch [1/5] | Batch #3 | Batch Accuracy 16.67%
# Epoch [1/5] | Batch #4 | Batch Accuracy 26.56%
# Epoch [1/5] | Batch #5 | Batch Accuracy 33.12%
# Epoch [1/5] | Batch #6 | Batch Accuracy 37.50%
# Epoch [1/5] | Batch #7 | Batch Accuracy 40.18%
# Epoch [1/5] | Batch #8 | Batch Accuracy 44.53%
# Epoch [1/5] | Batch #9 | Batch Accuracy 47.22%
# Epoch [1/5] | Batch #10 | Batch Accuracy 49.38%
# Epoch [1/5] | Batch #11 | Batch Accuracy 51.99%
# Epoch [1/5] | Batch #12 | Batch Accuracy 53.12%
# Epoch [1/5] | Batch #13 | Batch Accuracy 55.29%
# Epoch [1/5] | Batch #14 | Batch Accuracy 57.14%
# Epoch [1/5] | Batch #15 | Batch Accuracy 58.54%
# Epoch [1/5] | Batch #16 | Batch Accuracy 59.77%
# Epoch [1/5] | Batch #17 | Batch Accuracy 61.40%
# Epoch [1/5] | Batch #18 | Batch Accuracy 62.33%
# Epoch [1/5] | Batch #19 | Batch Accuracy 63.65%
# Epoch [1/5] | Batch #20 | Batch Accuracy 64.53%
# Epoch [1/5] | Batch #21 | Batch Accuracy 65.03%
# Epoch [1/5] | Batch #22 | Batch Accuracy 65.91%
# Epoch [1/5] | Batch #23 | Batch Accuracy 66.85%
# Epoch [1/5] | Batch #24 | Batch Accuracy 67.32%
# Epoch [1/5] | Batch #25 | Batch Accuracy 67.88%
# Epoch [1/5] | Batch #26 | Batch Accuracy 68.51%
# Epoch [1/5] | Batch #27 | Batch Accuracy 69.56%
# Epoch [1/5] | Batch #28 | Batch Accuracy 69.98%
# Epoch [1/5] | Batch #29 | Batch Accuracy 70.58%
# Epoch [1/5] | Batch #30 | Batch Accuracy 71.25%
# Epoch [1/5] | Batch #31 | Batch Accuracy 71.88%
# Epoch [1/5] | Batch #32 | Batch Accuracy 72.46%
# Epoch [1/5] | Batch #33 | Batch Accuracy 72.92%
# Epoch [1/5] | Batch #34 | Batch Accuracy 73.44%
# Epoch [1/5] | Batch #35 | Batch Accuracy 74.20%
# Epoch [1/5] | Batch #36 | Batch Accuracy 74.48%
# Epoch [1/5] | Batch #37 | Batch Accuracy 74.66%
# Epoch [1/5] | Batch #38 | Batch Accuracy 75.00%
# Epoch [1/5] | Batch #39 | Batch Accuracy 75.40%
# Epoch [1/5] | Batch #40 | Batch Accuracy 75.70%
# Epoch [1/5] | Batch #41 | Batch Accuracy 76.14%
# Epoch [1/5] | Batch #42 | Batch Accuracy 76.56%
# Epoch [1/5] | Batch #43 | Batch Accuracy 76.89%
# Epoch [1/5] | Batch #44 | Batch Accuracy 77.27%
# Epoch [1/5] | Batch #45 | Batch Accuracy 77.50%
# Epoch [1/5] | Batch #46 | Batch Accuracy 77.72%
# Epoch [1/5] | Batch #47 | Batch Accuracy 78.12%
# Epoch [1/5] | Batch #48 | Batch Accuracy 78.39%
# Epoch [1/5] | Batch #49 | Batch Accuracy 78.70%
# Epoch [1/5] | Batch #50 | Batch Accuracy 78.88%
# Epoch [1/5] | Batch #51 | Batch Accuracy 79.23%
# Epoch [1/5] | Batch #52 | Batch Accuracy 79.57%
# Epoch [1/5] | Batch #53 | Batch Accuracy 79.72%
# Epoch [1/5] | Batch #54 | Batch Accuracy 80.03%
# Epoch [1/5] | Batch #55 | Batch Accuracy 80.17%
# Epoch [1/5] | Batch #56 | Batch Accuracy 80.47%
# Epoch [1/5] | Batch #57 | Batch Accuracy 80.70%
# Epoch [1/5] | Batch #58 | Batch Accuracy 80.98%
# Epoch [1/5] | Batch #59 | Batch Accuracy 81.09%
# Epoch [1/5] | Batch #60 | Batch Accuracy 81.20%
# Epoch [1/5] | Batch #61 | Batch Accuracy 81.35%
# Epoch [1/5] Train Loss: 0.5418 | Train Acc: 81.35% | Val Acc: 88.70% | Val Loss: 0.33%
# Epoch [2/5] | Batch #62 | Batch Accuracy 96.88%
# Epoch [2/5] | Batch #63 | Batch Accuracy 95.31%
# Epoch [2/5] | Batch #64 | Batch Accuracy 96.88%
# Epoch [2/5] | Batch #65 | Batch Accuracy 96.88%
# Epoch [2/5] | Batch #66 | Batch Accuracy 97.50%
# Epoch [2/5] | Batch #67 | Batch Accuracy 97.40%
# Epoch [2/5] | Batch #68 | Batch Accuracy 97.32%
# Epoch [2/5] | Batch #69 | Batch Accuracy 97.27%
# Epoch [2/5] | Batch #70 | Batch Accuracy 97.22%
# Epoch [2/5] | Batch #71 | Batch Accuracy 97.19%
# Epoch [2/5] | Batch #72 | Batch Accuracy 97.16%
# Epoch [2/5] | Batch #73 | Batch Accuracy 97.14%
# Epoch [2/5] | Batch #74 | Batch Accuracy 96.39%
# Epoch [2/5] | Batch #75 | Batch Accuracy 95.98%
# Epoch [2/5] | Batch #76 | Batch Accuracy 95.83%
# Epoch [2/5] | Batch #77 | Batch Accuracy 96.09%
# Epoch [2/5] | Batch #78 | Batch Accuracy 95.96%
# Epoch [2/5] | Batch #79 | Batch Accuracy 96.18%
# Epoch [2/5] | Batch #80 | Batch Accuracy 96.38%
# Epoch [2/5] | Batch #81 | Batch Accuracy 96.41%
# Epoch [2/5] | Batch #82 | Batch Accuracy 96.13%
# Epoch [2/5] | Batch #83 | Batch Accuracy 96.16%
# Epoch [2/5] | Batch #84 | Batch Accuracy 96.20%
# Epoch [2/5] | Batch #85 | Batch Accuracy 95.96%
# Epoch [2/5] | Batch #86 | Batch Accuracy 95.88%
# Epoch [2/5] | Batch #87 | Batch Accuracy 95.67%
# Epoch [2/5] | Batch #88 | Batch Accuracy 95.72%
# Epoch [2/5] | Batch #89 | Batch Accuracy 95.76%
# Epoch [2/5] | Batch #90 | Batch Accuracy 95.80%
# Epoch [2/5] | Batch #91 | Batch Accuracy 95.83%
# Epoch [2/5] | Batch #92 | Batch Accuracy 95.87%
# Epoch [2/5] | Batch #93 | Batch Accuracy 95.70%
# Epoch [2/5] | Batch #94 | Batch Accuracy 95.83%
# Epoch [2/5] | Batch #95 | Batch Accuracy 95.86%
# Epoch [2/5] | Batch #96 | Batch Accuracy 95.98%
# Epoch [2/5] | Batch #97 | Batch Accuracy 95.92%
# Epoch [2/5] | Batch #98 | Batch Accuracy 96.03%
# Epoch [2/5] | Batch #99 | Batch Accuracy 95.97%
# Epoch [2/5] | Batch #100 | Batch Accuracy 96.07%
# Epoch [2/5] | Batch #101 | Batch Accuracy 96.02%
# Epoch [2/5] | Batch #102 | Batch Accuracy 96.04%
# Epoch [2/5] | Batch #103 | Batch Accuracy 96.06%
# Epoch [2/5] | Batch #104 | Batch Accuracy 96.08%
# Epoch [2/5] | Batch #105 | Batch Accuracy 96.16%
# Epoch [2/5] | Batch #106 | Batch Accuracy 95.83%
# Epoch [2/5] | Batch #107 | Batch Accuracy 95.86%
# Epoch [2/5] | Batch #108 | Batch Accuracy 95.81%
# Epoch [2/5] | Batch #109 | Batch Accuracy 95.83%
# Epoch [2/5] | Batch #110 | Batch Accuracy 95.92%
# Epoch [2/5] | Batch #111 | Batch Accuracy 95.94%
# Epoch [2/5] | Batch #112 | Batch Accuracy 95.89%
# Epoch [2/5] | Batch #113 | Batch Accuracy 95.97%
# Epoch [2/5] | Batch #114 | Batch Accuracy 95.99%
# Epoch [2/5] | Batch #115 | Batch Accuracy 96.01%
# Epoch [2/5] | Batch #116 | Batch Accuracy 96.02%
# Epoch [2/5] | Batch #117 | Batch Accuracy 96.04%
# Epoch [2/5] | Batch #118 | Batch Accuracy 96.05%
# Epoch [2/5] | Batch #119 | Batch Accuracy 96.12%
# Epoch [2/5] | Batch #120 | Batch Accuracy 96.03%
# Epoch [2/5] | Batch #121 | Batch Accuracy 96.04%
# Epoch [2/5] | Batch #122 | Batch Accuracy 96.11%
# Epoch [2/5] Train Loss: 0.1525 | Train Acc: 96.11% | Val Acc: 91.83% | Val Loss: 0.26%
# Epoch [3/5] | Batch #123 | Batch Accuracy 96.88%
# Epoch [3/5] | Batch #124 | Batch Accuracy 96.88%
# Epoch [3/5] | Batch #125 | Batch Accuracy 96.88%
# Epoch [3/5] | Batch #126 | Batch Accuracy 96.88%
# Epoch [3/5] | Batch #127 | Batch Accuracy 96.88%
# Epoch [3/5] | Batch #128 | Batch Accuracy 96.35%
# Epoch [3/5] | Batch #129 | Batch Accuracy 96.43%
# Epoch [3/5] | Batch #130 | Batch Accuracy 96.48%
# Epoch [3/5] | Batch #131 | Batch Accuracy 95.83%
# Epoch [3/5] | Batch #132 | Batch Accuracy 94.69%
# Epoch [3/5] | Batch #133 | Batch Accuracy 95.17%
# Epoch [3/5] | Batch #134 | Batch Accuracy 95.31%
# Epoch [3/5] | Batch #135 | Batch Accuracy 95.67%
# Epoch [3/5] | Batch #136 | Batch Accuracy 95.98%
# Epoch [3/5] | Batch #137 | Batch Accuracy 96.25%
# Epoch [3/5] | Batch #138 | Batch Accuracy 96.48%
# Epoch [3/5] | Batch #139 | Batch Accuracy 96.69%
# Epoch [3/5] | Batch #140 | Batch Accuracy 96.35%
# Epoch [3/5] | Batch #141 | Batch Accuracy 96.55%
# Epoch [3/5] | Batch #142 | Batch Accuracy 96.56%
# Epoch [3/5] | Batch #143 | Batch Accuracy 96.58%
# Epoch [3/5] | Batch #144 | Batch Accuracy 96.59%
# Epoch [3/5] | Batch #145 | Batch Accuracy 96.74%
# Epoch [3/5] | Batch #146 | Batch Accuracy 96.74%
# Epoch [3/5] | Batch #147 | Batch Accuracy 96.62%
# Epoch [3/5] | Batch #148 | Batch Accuracy 96.75%
# Epoch [3/5] | Batch #149 | Batch Accuracy 96.76%
# Epoch [3/5] | Batch #150 | Batch Accuracy 96.54%
# Epoch [3/5] | Batch #151 | Batch Accuracy 96.55%
# Epoch [3/5] | Batch #152 | Batch Accuracy 96.46%
# Epoch [3/5] | Batch #153 | Batch Accuracy 96.47%
# Epoch [3/5] | Batch #154 | Batch Accuracy 96.39%
# Epoch [3/5] | Batch #155 | Batch Accuracy 96.31%
# Epoch [3/5] | Batch #156 | Batch Accuracy 96.32%
# Epoch [3/5] | Batch #157 | Batch Accuracy 96.43%
# Epoch [3/5] | Batch #158 | Batch Accuracy 96.53%
# Epoch [3/5] | Batch #159 | Batch Accuracy 96.62%
# Epoch [3/5] | Batch #160 | Batch Accuracy 96.71%
# Epoch [3/5] | Batch #161 | Batch Accuracy 96.71%
# Epoch [3/5] | Batch #162 | Batch Accuracy 96.64%
# Epoch [3/5] | Batch #163 | Batch Accuracy 96.72%
# Epoch [3/5] | Batch #164 | Batch Accuracy 96.80%
# Epoch [3/5] | Batch #165 | Batch Accuracy 96.80%
# Epoch [3/5] | Batch #166 | Batch Accuracy 96.73%
# Epoch [3/5] | Batch #167 | Batch Accuracy 96.74%
# Epoch [3/5] | Batch #168 | Batch Accuracy 96.74%
# Epoch [3/5] | Batch #169 | Batch Accuracy 96.61%
# Epoch [3/5] | Batch #170 | Batch Accuracy 96.61%
# Epoch [3/5] | Batch #171 | Batch Accuracy 96.62%
# Epoch [3/5] | Batch #172 | Batch Accuracy 96.50%
# Epoch [3/5] | Batch #173 | Batch Accuracy 96.51%
# Epoch [3/5] | Batch #174 | Batch Accuracy 96.51%
# Epoch [3/5] | Batch #175 | Batch Accuracy 96.58%
# Epoch [3/5] | Batch #176 | Batch Accuracy 96.53%
# Epoch [3/5] | Batch #177 | Batch Accuracy 96.59%
# Epoch [3/5] | Batch #178 | Batch Accuracy 96.48%
# Epoch [3/5] | Batch #179 | Batch Accuracy 96.55%
# Epoch [3/5] | Batch #180 | Batch Accuracy 96.55%
# Epoch [3/5] | Batch #181 | Batch Accuracy 96.56%
# Epoch [3/5] | Batch #182 | Batch Accuracy 96.56%
# Epoch [3/5] | Batch #183 | Batch Accuracy 96.52%
# Epoch [3/5] Train Loss: 0.1088 | Train Acc: 96.52% | Val Acc: 93.27% | Val Loss: 0.22%
# Epoch [4/5] | Batch #184 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #185 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #186 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #187 | Batch Accuracy 96.09%
# Epoch [4/5] | Batch #188 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #189 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #190 | Batch Accuracy 96.88%
# Epoch [4/5] | Batch #191 | Batch Accuracy 97.27%
# Epoch [4/5] | Batch #192 | Batch Accuracy 97.57%
# Epoch [4/5] | Batch #193 | Batch Accuracy 97.50%
# Epoch [4/5] | Batch #194 | Batch Accuracy 97.73%
# Epoch [4/5] | Batch #195 | Batch Accuracy 97.40%
# Epoch [4/5] | Batch #196 | Batch Accuracy 97.36%
# Epoch [4/5] | Batch #197 | Batch Accuracy 97.54%
# Epoch [4/5] | Batch #198 | Batch Accuracy 97.71%
# Epoch [4/5] | Batch #199 | Batch Accuracy 97.85%
# Epoch [4/5] | Batch #200 | Batch Accuracy 97.98%
# Epoch [4/5] | Batch #201 | Batch Accuracy 97.92%
# Epoch [4/5] | Batch #202 | Batch Accuracy 97.70%
# Epoch [4/5] | Batch #203 | Batch Accuracy 97.81%
# Epoch [4/5] | Batch #204 | Batch Accuracy 97.47%
# Epoch [4/5] | Batch #205 | Batch Accuracy 97.59%
# Epoch [4/5] | Batch #206 | Batch Accuracy 97.69%
# Epoch [4/5] | Batch #207 | Batch Accuracy 97.79%
# Epoch [4/5] | Batch #208 | Batch Accuracy 97.75%
# Epoch [4/5] | Batch #209 | Batch Accuracy 97.60%
# Epoch [4/5] | Batch #210 | Batch Accuracy 97.57%
# Epoch [4/5] | Batch #211 | Batch Accuracy 97.54%
# Epoch [4/5] | Batch #212 | Batch Accuracy 97.63%
# Epoch [4/5] | Batch #213 | Batch Accuracy 97.71%
# Epoch [4/5] | Batch #214 | Batch Accuracy 97.78%
# Epoch [4/5] | Batch #215 | Batch Accuracy 97.75%
# Epoch [4/5] | Batch #216 | Batch Accuracy 97.63%
# Epoch [4/5] | Batch #217 | Batch Accuracy 97.70%
# Epoch [4/5] | Batch #218 | Batch Accuracy 97.77%
# Epoch [4/5] | Batch #219 | Batch Accuracy 97.83%
# Epoch [4/5] | Batch #220 | Batch Accuracy 97.80%
# Epoch [4/5] | Batch #221 | Batch Accuracy 97.70%
# Epoch [4/5] | Batch #222 | Batch Accuracy 97.60%
# Epoch [4/5] | Batch #223 | Batch Accuracy 97.66%
# Epoch [4/5] | Batch #224 | Batch Accuracy 97.64%
# Epoch [4/5] | Batch #225 | Batch Accuracy 97.69%
# Epoch [4/5] | Batch #226 | Batch Accuracy 97.67%
# Epoch [4/5] | Batch #227 | Batch Accuracy 97.73%
# Epoch [4/5] | Batch #228 | Batch Accuracy 97.78%
# Epoch [4/5] | Batch #229 | Batch Accuracy 97.83%
# Epoch [4/5] | Batch #230 | Batch Accuracy 97.87%
# Epoch [4/5] | Batch #231 | Batch Accuracy 97.79%
# Epoch [4/5] | Batch #232 | Batch Accuracy 97.70%
# Epoch [4/5] | Batch #233 | Batch Accuracy 97.75%
# Epoch [4/5] | Batch #234 | Batch Accuracy 97.79%
# Epoch [4/5] | Batch #235 | Batch Accuracy 97.84%
# Epoch [4/5] | Batch #236 | Batch Accuracy 97.88%
# Epoch [4/5] | Batch #237 | Batch Accuracy 97.86%
# Epoch [4/5] | Batch #238 | Batch Accuracy 97.84%
# Epoch [4/5] | Batch #239 | Batch Accuracy 97.88%
# Epoch [4/5] | Batch #240 | Batch Accuracy 97.92%
# Epoch [4/5] | Batch #241 | Batch Accuracy 97.95%
# Epoch [4/5] | Batch #242 | Batch Accuracy 97.99%
# Epoch [4/5] | Batch #243 | Batch Accuracy 98.02%
# Epoch [4/5] | Batch #244 | Batch Accuracy 98.00%
# Epoch [4/5] Train Loss: 0.0705 | Train Acc: 98.00% | Val Acc: 94.95% | Val Loss: 0.17%
# Epoch [5/5] | Batch #245 | Batch Accuracy 96.88%
# Epoch [5/5] | Batch #246 | Batch Accuracy 98.44%
# Epoch [5/5] | Batch #247 | Batch Accuracy 97.92%
# Epoch [5/5] | Batch #248 | Batch Accuracy 98.44%
# Epoch [5/5] | Batch #249 | Batch Accuracy 98.75%
# Epoch [5/5] | Batch #250 | Batch Accuracy 98.96%
# Epoch [5/5] | Batch #251 | Batch Accuracy 99.11%
# Epoch [5/5] | Batch #252 | Batch Accuracy 99.22%
# Epoch [5/5] | Batch #253 | Batch Accuracy 98.96%
# Epoch [5/5] | Batch #254 | Batch Accuracy 99.06%
# Epoch [5/5] | Batch #255 | Batch Accuracy 99.15%
# Epoch [5/5] | Batch #256 | Batch Accuracy 98.96%
# Epoch [5/5] | Batch #257 | Batch Accuracy 99.04%
# Epoch [5/5] | Batch #258 | Batch Accuracy 98.66%
# Epoch [5/5] | Batch #259 | Batch Accuracy 98.75%
# Epoch [5/5] | Batch #260 | Batch Accuracy 98.83%
# Epoch [5/5] | Batch #261 | Batch Accuracy 98.90%
# Epoch [5/5] | Batch #262 | Batch Accuracy 98.78%
# Epoch [5/5] | Batch #263 | Batch Accuracy 98.68%
# Epoch [5/5] | Batch #264 | Batch Accuracy 98.59%
# Epoch [5/5] | Batch #265 | Batch Accuracy 98.66%
# Epoch [5/5] | Batch #266 | Batch Accuracy 98.58%
# Epoch [5/5] | Batch #267 | Batch Accuracy 98.51%
# Epoch [5/5] | Batch #268 | Batch Accuracy 98.57%
# Epoch [5/5] | Batch #269 | Batch Accuracy 98.50%
# Epoch [5/5] | Batch #270 | Batch Accuracy 98.56%
# Epoch [5/5] | Batch #271 | Batch Accuracy 98.50%
# Epoch [5/5] | Batch #272 | Batch Accuracy 98.55%
# Epoch [5/5] | Batch #273 | Batch Accuracy 98.60%
# Epoch [5/5] | Batch #274 | Batch Accuracy 98.65%
# Epoch [5/5] | Batch #275 | Batch Accuracy 98.59%
# Epoch [5/5] | Batch #276 | Batch Accuracy 98.63%
# Epoch [5/5] | Batch #277 | Batch Accuracy 98.67%
# Epoch [5/5] | Batch #278 | Batch Accuracy 98.71%
# Epoch [5/5] | Batch #279 | Batch Accuracy 98.66%
# Epoch [5/5] | Batch #280 | Batch Accuracy 98.70%
# Epoch [5/5] | Batch #281 | Batch Accuracy 98.73%
# Epoch [5/5] | Batch #282 | Batch Accuracy 98.77%
# Epoch [5/5] | Batch #283 | Batch Accuracy 98.72%
# Epoch [5/5] | Batch #284 | Batch Accuracy 98.67%
# Epoch [5/5] | Batch #285 | Batch Accuracy 98.70%
# Epoch [5/5] | Batch #286 | Batch Accuracy 98.74%
# Epoch [5/5] | Batch #287 | Batch Accuracy 98.76%
# Epoch [5/5] | Batch #288 | Batch Accuracy 98.79%
# Epoch [5/5] | Batch #289 | Batch Accuracy 98.82%
# Epoch [5/5] | Batch #290 | Batch Accuracy 98.85%
# Epoch [5/5] | Batch #291 | Batch Accuracy 98.87%
# Epoch [5/5] | Batch #292 | Batch Accuracy 98.83%
# Epoch [5/5] | Batch #293 | Batch Accuracy 98.85%
# Epoch [5/5] | Batch #294 | Batch Accuracy 98.81%
# Epoch [5/5] | Batch #295 | Batch Accuracy 98.84%
# Epoch [5/5] | Batch #296 | Batch Accuracy 98.86%
# Epoch [5/5] | Batch #297 | Batch Accuracy 98.88%
# Epoch [5/5] | Batch #298 | Batch Accuracy 98.84%
# Epoch [5/5] | Batch #299 | Batch Accuracy 98.86%
# Epoch [5/5] | Batch #300 | Batch Accuracy 98.88%
# Epoch [5/5] | Batch #301 | Batch Accuracy 98.90%
# Epoch [5/5] | Batch #302 | Batch Accuracy 98.87%
# Epoch [5/5] | Batch #303 | Batch Accuracy 98.89%
# Epoch [5/5] | Batch #304 | Batch Accuracy 98.91%
# Epoch [5/5] | Batch #305 | Batch Accuracy 98.87%
# Epoch [5/5] Train Loss: 0.0490 | Train Acc: 98.87% | Val Acc: 94.71% | Val Loss: 0.18%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▂▂▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▅▆██</td></tr><tr><td>validation_loss</td><td>█▅▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.04897</td></tr><tr><td>validation_accuracy</td><td>94.71154</td></tr><tr><td>validation_loss</td><td>0.17795</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ryan-HappyWhale-SpeciesDataset-hyperparameters_mod3</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/yceh4zc7' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/yceh4zc7</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_234813-yceh4zc7/logs</code>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 88
#      84     wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})
#      86 wandb.finish()
# ---> 88 plt.plot(range(epochs), validation_accuracy_list, color = "magenta")
#      89 plt.xlabel("Epoch number")
#      90 plt.ylabel("Valiation accuracy")
#
# NameError: name 'validation_accuracy_list' is not defined

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_2456973/2928404987.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# The changes were not really successful overall as the validation accuracy dropped to 94.71154%. Interestingly, the previous iteration had trouble correctly identifying fin whales, but this model got all the fin whales. There may be some sort of tradeoff then here in the transformations used. It would be interesting to look at the fin whale images and see if there was any reason that identification was better with added transformations. The amount of fin whales in the data is small though, so the change in model performance could be due to chance with how the batches are handled.

# %% [markdown]
# <font color='magenta'>Summarize your 3 steps, their success, and what you learned (5 pts)

# %% [markdown]
# It definitely seems like the first two steps added a lot to the model. Lowering the learning rate, changing the optimizer, using the preloaded model and lowering the batch size all together made huge improvements. I think it would be interesting to try and change one thing at a time rather than two or so like I did so I could discern the effects of each change individually. It all seemed to work pretty well though, and I learned that making changes by slowly adding to a model seems like a great way to build an effective one. It seems like you could do this forever, and even then there might be tradeoffs like how my last model had a lower overall accuracy but did a great job with the fin whales.

# %% [markdown]
# *Your answer here*
